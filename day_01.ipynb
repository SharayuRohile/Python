# %%
# pthyon day one

# %%
## python day 1

# %%
name="Sharayu"
city="Pune"

# %%
line="It's nice day"

# %%
line
# Out:
# "It's nice day"

# %%
name="Aish"

# %%
name="Sharayu"
city="Pune"
phone="Phone number"

# %%
print(city)
print(name)
# Out:
# Pune
# Sharayu

# %%
# Create the variable
name="Sharayu" #string
age=22 #integer
height=6.0 #float
exam_clear=True #boolean

# %%
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# #string="Sharayu"
# #integer=23
# #float=10.5
# #boolean=True/False

# %%
# Data Structures : tuple , list

# %%
cities = ("PUNE","MUMBAI") # Tuple
towns = ["PUNE","MUMBAI"] # List

# %%
name="Rahul"
name="Ajay"

# %%
today = ["today is rainy day","it is 25 degree celcius"]

# %%
# Data Types
# Primitive - single type of data can be stored - int ,float, bool, string, complex
# non primitive - different types data can be stored - list,tuple,set,dict

# %%
# Type casting - Implict and Explicit
# Implicit - automatically convert
# Explicit - manual conversion

# Implicit
a=10
b=3
c=a/b
print(c)

# Explicit
y=50
e=float(y)
print(e,type(e))

a="60"
# Out:
# 3.3333333333333335
# 50.0 <class 'float'>

# %%
# Operators - +,-,*,/
# Operands - a+b here a is operand
# Types
# Arithmetic , Assignment , Comparison , Logical , Identity - is , is not

# Identity Is - memory location compare 
x=10
y=20
print("x location is",id(x))
print("y location is",id(y))
print(x is y)

x=10
y=10
print("x location is",id(x))
print("y location is",id(y))
print(x is y)
# Out:
# x location is 140721895957912
# y location is 140721895958232
# False
# x location is 140721895957912
# y location is 140721895957912
# True

# %%
# Conditions 
# Syntax - 
if cond1 : 
    statement()
else:
    statement()

# %%
age=25
if age>=18:
    print("Applicable")
else:
    print("Not applicable")
# Out:
# Applicable

# %%
age=int(input("Enter the age of a person : "))
if age>=18:
    print("Applicable")
else:
    print("Not applicable")
# Out:
# Applicable

# %%
# Write the conditions take the marks from user and check the students pass or fail

marks=int(input("Enter the marks of Student: "))
if marks>=35:
    print("You pass the exam")
else:
    print("You fail the exam")
# Out:
# You pass the exam

# %%
username=input("Enter the username: ")


username="sharayu"
password=123

if username=="sharayu":
    print("login Successful")
else:
    print("Invalid Username and Password")
# Out:
# login Successful

# %%
username="sharayu"
password=123

u = input("Enter the username: ")
p = int(input("Enter the password: "))

if u == username and p == password:
     print("login Successful")
else:
    print("Invalid Username and Password")
# Out:
# Invalid Username and Password

# %%
print("********* MINI CALCULATOR **********")

no1=int(input("Enter the first number : "))
no2=int(input("Enter the second number : "))
op=input("Enter the operator(+,-,/,*) : " )

if op == "+":
    print("The Sum Is - ", no1+no2)

elif op == "-":
    print("The Substraction Is - ", no1-no2)


elif op == "-":
    print("The Substraction Is - ", no1-no2)

elif op == "/":
    print("The Divison Is - ", no1/no2)

elif op == "*":
    print("The Multiplication Is - ", no1*no2)

else:
    print("Please enter proper operator ..................!")
# Out:
# ********* MINI CALCULATOR **********
# The Sum Is -  40

# %%
num=int(input("Enter the number : "))

if num % 2 == 0 :
    print("Even number")

else:
    print("Odd number")
# Out:
# Even number

# %%
num=int(input("Enter the number : "))

if num >= 0 :
    print("Positive number")

else:
    print("Negative number")
# Out:
# Negative number

# %%
num1=int(input(" Enter the first number : "))
num2=int(input(" Enter the second number : "))

if num1 > num2 :
    print(" num1 is greater ")

else:
    print(" num2 is greater ")
# Out:
#  num2 is greater
