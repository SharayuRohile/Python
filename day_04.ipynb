# %%
# Conditions

# %%
# Green : GO , Red : Stop
signal="Green"

if signal=="Green":
    print(" You can go ")

else:
    print("Stop")
# Out:
#  You can go

# %%
# Weekend : movie , Weekday : Work
day=input()

if day=="Weekend":
    print(" You can watch movie")

else:
    print(" you have to do study")
# Out:
#  you have to do study

# %%
# Hot And Cold
day=input()

if day=="Sunny":
    print("Its hot Outside")

else:
    print("Its Cold")
# Out:
# Its hot Outside

# %%
# Fever / Not Fever
temp=int(input("Enter Temprature"))

if temp>=35:
    print(" Fever ")
else:
    print(" Not Fever ")
# Out:
#  Not Fever

# %%
# Voting Card
age=int(input())

if age>=18:
    print(" You can apply for voting card ")

else:
    print(" You can't apply ")
# Out:
#  You can't apply

# %%
# Pass or Fail
marks=int(input("Enter Marks"))

if marks>=35:
    print("You pass the exam")

else:
    print("You Fail")
# Out:
# You pass the exam

# %%
# Days
day=int(input())

if day==1:
    print("Monday")

elif day==2:
    print("Tuesday")

elif day==3:
    print("Wednesday")

elif day==4:
    print("Thursday")

elif day==5:
    print("Friday")

elif day==6:
    print("Saturday")

elif day==7:
    print("Sunday")
# Out:
# Friday

# %%
# Traffic Signal
signal=input()

if signal=="Green":
    print(" You can go ")
 
elif signal=="Red":
     print("Stop")
    
else:
    print("Alert")
# Out:
# Stop
