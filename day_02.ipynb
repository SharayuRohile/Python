# %%
# create variable
a=10
b="raj"

# %%
a="10"
b=20
c=10.0

# %%
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
b=int(b)

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
# create a variable with integer and convert in the float
# create a variable with float and convert in the int
# create a variable with string and convert in the float and then in int
# create a self bio using variables
# Name
# hobbies # minimum 4
# college
# sports_play #minimum 2
# write about python in 2 lines

# %%
a=10

# %%
a=float(a)

# %%
print(a)
# Out:
# 20.0

# %%
b=20.0

# %%
b=int(b)

# %%
print(b)
# Out:
# 20

# %%
c='10'

# %%
c=float(c)

# %%
print(c)
# Out:
# 10.0

# %%
c=int(c)

# %%
print(c)
# Out:
# 10

# %%
name="Sharayu"
hobbies=["travelling","Drawing","Cooking","Singing"]
college="Bharati Vidyapeeth"
sports_play=("Badminton","Cricket")

# %%
print(name)
print(hobbies)
print(college)
print(sports_play)
# Out:
# Sharayu
# ['travelling', 'Drawing', 'Cooking', 'Singing']
# Bharati Vidyapeeth
# ('Badminton', 'Cricket')

# %%
lyrics=""" Waedeul geuri daundwaeisseo?
Mwoga munjeya say something
Bunwigiga geobna ssahae
Yosaeneun ireon ge yuhaenginga
Waedeul geuri jaemieopseo?
A geugeon nado machangaji
Tell me what I got to do
Geubhan daero beullutuseu kyeo
"""

# %%
print(lyrics)
# Out:
#  Waedeul geuri daundwaeisseo?
# Mwoga munjeya say something
# Bunwigiga geobna ssahae
# Yosaeneun ireon ge yuhaenginga
# Waedeul geuri jaemieopseo?
# A geugeon nado machangaji
# Tell me what I got to do
# Geubhan daero beullutuseu kyeo

# %%
cities=["pune","Delhi","Blr","Nagpur","Yavatmal","Mumbai","Hyd"]

# %%
cities[3]
# Out:
# 'Nagpur'

# %%
# python indexing starts from 0
# from ending it from -1

# %%
cities[0:2]
# Out:
# ['pune', 'Delhi']

# %%
cities[3:7]
# Out:
# ['Nagpur', 'Yavatmal', 'Mumbai', 'Hyd']

# %%
cities[2:]
# Out:
# ['Blr', 'Nagpur', 'Yavatmal', 'Mumbai', 'Hyd']

# %%
cities[-1]
# Out:
# 'Hyd'

# %%
cities[-3:-7]
# Out:
# []

# %%
cities[::-1]
# Out:
# ['Hyd', 'Mumbai', 'Yavatmal', 'Nagpur', 'Blr', 'Delhi', 'pune']
