# %%
# f string
# When we want to print long sentence at that time we use f string

# %%
city = "Pune"
temp = 29

print("Todays weather in " ,city , "is" ,temp )
# Out:
# Todays weather in  Pune is 29

# %%
print(f"{city} {temp}")
# Out:
# Pune 29

# %%
print(f" Todays weather in {city} is {temp}")
# Out:
#  Todays weather in Pune is 29

# %%
city = "pune"
temp = 29
weather = "rainy"
time = 8

print(f"The city is {city} and tempreature is {temp} as the weather is {weather} so go out at {time}")
# Out:
# The city is pune and tempreature is 29 as the weather is rainy so go out at 8
